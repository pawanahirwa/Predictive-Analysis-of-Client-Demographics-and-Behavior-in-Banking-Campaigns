# %% [markdown]
# # 🏦 Predictive Analysis of Client Demographics and Behavior in Banking Campaigns
#
# **Dataset:** Portuguese Bank Marketing Campaign (45,216 records)
# **Goal:** Exploratory Data Analysis (EDA) to understand client demographics, financial behavior, and campaign interactions — and what drives term deposit subscriptions.
#
# ---

# %% [markdown]
# ## 📦 Setup & Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress FutureWarnings for cleaner output
import warnings
warnings.filterwarnings('ignore')

# Load the dataset
# Download from: https://www.kaggle.com/datasets/janiobachmann/bank-marketing-dataset
data = pd.read_csv('bank.csv')

print("Dataset shape:", data.shape)
print("\nColumn names:", list(data.columns))
print("\nFirst 5 rows:")
data.head()

# %%
# Quick overview of the dataset
print("Dataset Info:")
print(data.info())
print("\nMissing values:")
print(data.isnull().sum())

# %% [markdown]
# ---
# ## Q.1 What is the distribution of age among the clients?

# %%
# Summary statistics of the age column
print(data['age'].describe())

# Plotting the age distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['age'], bins=30, kde=True)
plt.title('Distribution of Age among Clients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.2 How does the job type vary among the clients?

# %%
# Summary of job type column
print(data['job'].value_counts())
print("\nUnique job types:", data['job'].unique())

# Plotting the job type distribution
plt.figure(figsize=(12, 8))
sns.countplot(y=data['job'], order=data['job'].value_counts().index,
              hue=data['job'], palette='viridis', legend=False)
plt.title('Distribution of Job Types among Clients')
plt.xlabel('Count')
plt.ylabel('Job Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.3 What is the marital status distribution of the clients?

# %%
# Summary of marital status column
marital_status_counts = data['marital'].value_counts()
print(marital_status_counts)
print("\nUnique marital statuses:", data['marital'].unique())

# Plotting the marital status distribution
plt.figure(figsize=(10, 6))
sns.countplot(x=data['marital'], order=data['marital'].value_counts().index,
              hue=data['marital'], palette='viridis', legend=False)
plt.title('Distribution of Marital Status among Clients')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.4 What is the level of education among the clients?

# %%
# Summary of education column
education_counts = data['education'].value_counts()
print(education_counts)
print("\nUnique education levels:", data['education'].unique())

# Plotting the education level distribution
plt.figure(figsize=(10, 6))
sns.countplot(x=data['education'], order=data['education'].value_counts().index,
              hue=data['education'], palette='viridis', legend=False)
plt.title('Distribution of Education Levels among Clients')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.5 What proportion of clients have credit in default?

# %%
# Summary of default column
default_counts = data['default'].value_counts()
print(default_counts)
print("\nUnique values:", data['default'].unique())

# Calculate the proportion of clients with credit in default
total_clients = len(data)
clients_with_default = default_counts['yes']
proportion_with_default = clients_with_default / total_clients
print(f"\nProportion of clients with credit in default: {proportion_with_default:.2%}")

# Pie chart
plt.figure(figsize=(7, 7))
plt.pie(default_counts, labels=default_counts.index, autopct='%1.1f%%',
        colors=['#3B528B', '#21908C'])
plt.title('Proportion of Clients with Credit in Default')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.6 What is the distribution of average yearly balance among the clients?

# %%
# Summary statistics of the balance column
balance_summary = data['balance'].describe()
print(balance_summary)

# Plotting the balance distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['balance'], bins=30, kde=True)
plt.title('Distribution of Average Yearly Balance among Clients')
plt.xlabel('Balance')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.7 How many clients have housing loans?

# %%
# Count of clients with housing loans
housing_loan_counts = data['housing'].value_counts()
print(housing_loan_counts)

# Number of clients with housing loans
num_housing_loans = housing_loan_counts['yes']
print(f"Number of clients with housing loans: {num_housing_loans}")

# Bar chart
plt.figure(figsize=(8, 5))
sns.countplot(x=data['housing'], hue=data['housing'], palette='viridis', legend=False)
plt.title('Housing Loan Distribution among Clients')
plt.xlabel('Has Housing Loan')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.8 How many clients have personal loans?

# %%
# Count of clients with personal loans
personal_loan_counts = data['loan'].value_counts()
print(personal_loan_counts)

# Number of clients with personal loans
num_personal_loans = personal_loan_counts['yes']
print(f"Number of clients with personal loans: {num_personal_loans}")

# Bar chart
plt.figure(figsize=(8, 5))
sns.countplot(x=data['loan'], hue=data['loan'], palette='viridis', legend=False)
plt.title('Personal Loan Distribution among Clients')
plt.xlabel('Has Personal Loan')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.9 What are the communication types used for contacting clients during the campaign?

# %%
# Unique communication types
communication_types = data['contact'].unique()
print("Communication types:", communication_types)

# Count of each communication type
communication_type_counts = data['contact'].value_counts()
print(communication_type_counts)

# Bar chart
plt.figure(figsize=(8, 5))
sns.countplot(x=data['contact'], order=communication_type_counts.index,
              hue=data['contact'], palette='viridis', legend=False)
plt.title('Communication Types Used for Contacting Clients')
plt.xlabel('Contact Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.10 What is the distribution of the last contact day of the month?

# %%
# Plotting the last contact day of the month distribution
plt.figure(figsize=(14, 6))
day_order = sorted(data['day'].unique())
sns.countplot(x=data['day'], order=day_order, hue=data['day'], palette='viridis', legend=False)
plt.title('Distribution of Last Contact Day of the Month')
plt.xlabel('Day of Month')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.11 How does the last contact month vary among the clients?

# %%
# Unique contact months
contact_months = data['month'].unique()
print("Contact months:", contact_months)

# Count of each contact month
contact_month_counts = data['month'].value_counts()
print(contact_month_counts)

# Plotting the last contact month distribution
plt.figure(figsize=(12, 6))
sns.countplot(x=data['month'], order=contact_month_counts.index,
              hue=data['month'], palette='viridis', legend=False)
plt.title('Distribution of Last Contact Month')
plt.xlabel('Month')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.12 What is the distribution of the duration of the last contact?

# %%
# Summary statistics
print(data['duration'].describe())

# Plotting the duration of the last contact distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['duration'], bins=30, kde=True)
plt.title('Distribution of Duration of Last Contact')
plt.xlabel('Duration (seconds)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.13 How many contacts were performed during the campaign for each client?

# %%
# Summary statistics of campaign contacts
campaign_contacts_summary = data['campaign'].describe()
print(campaign_contacts_summary)

# Plotting — cap at 20 contacts for readability
plt.figure(figsize=(12, 6))
campaign_data = data[data['campaign'] <= 20]
sns.countplot(x=campaign_data['campaign'], hue=campaign_data['campaign'],
              palette='viridis', legend=False)
plt.title('Number of Contacts Performed During the Campaign for Each Client (capped at 20)')
plt.xlabel('Number of Contacts')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.14 What is the distribution of days passed since the client was last contacted from a previous campaign?

# %%
# Summary statistics of days passed since last contact
pdays_summary = data['pdays'].describe()
print(pdays_summary)
print("\nNote: -1 means the client was not previously contacted")

# Plotting the distribution (excluding -1 / not contacted)
plt.figure(figsize=(10, 6))
sns.histplot(data['pdays'], bins=30, kde=True)
plt.title('Distribution of Days Passed Since Last Contact from Previous Campaign')
plt.xlabel('Number of Days (-1 = not previously contacted)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# Separate view: only clients who were previously contacted
pdays_contacted = data[data['pdays'] != -1]['pdays']
print(f"\nClients previously contacted: {len(pdays_contacted)} ({len(pdays_contacted)/len(data)*100:.1f}%)")
print(f"Clients NOT previously contacted: {(data['pdays'] == -1).sum()}")

# %% [markdown]
# ---
# ## Q.15 How many contacts were performed before the current campaign for each client?

# %%
# Summary statistics of previous contacts
previous_contacts_summary = data['previous'].describe()
print(previous_contacts_summary)

# Plotting — cap at 15 for readability
plt.figure(figsize=(12, 6))
prev_data = data[data['previous'] <= 15]
sns.countplot(x=prev_data['previous'], hue=prev_data['previous'],
              palette='viridis', legend=False)
plt.title('Number of Contacts Performed Before the Current Campaign for Each Client')
plt.xlabel('Number of Previous Contacts')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.16 What were the outcomes of the previous marketing campaigns?

# %%
# Unique outcomes
previous_outcomes = data['poutcome'].unique()
print("Unique outcomes:", previous_outcomes)

# Count of each outcome
previous_outcome_counts = data['poutcome'].value_counts()
print(previous_outcome_counts)

# Plotting the outcomes of previous marketing campaigns
plt.figure(figsize=(10, 6))
sns.countplot(x=data['poutcome'], order=previous_outcome_counts.index,
              hue=data['poutcome'], palette='viridis', legend=False)
plt.title('Outcomes of Previous Marketing Campaigns')
plt.xlabel('Outcome')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.17 What is the distribution of clients who subscribed to a term deposit vs. those who did not?

# %%
# Count of clients who subscribed vs. those who did not
subscription_counts = data['y'].value_counts()
print(subscription_counts)
print(f"\nSubscription rate: {subscription_counts['yes']/len(data)*100:.1f}%")

# Bar chart
plt.figure(figsize=(8, 6))
sns.countplot(x=data['y'], hue=data['y'], palette='viridis', legend=False)
plt.title('Distribution of Clients Who Subscribed to a Term Deposit vs. Those Who Did Not')
plt.xlabel('Subscribed to Term Deposit')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# Pie chart
plt.figure(figsize=(7, 7))
plt.pie(subscription_counts, labels=['No', 'Yes'], autopct='%1.1f%%',
        colors=['#3B528B', '#5DC863'])
plt.title('Term Deposit Subscription Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Q.18 Are there any correlations between different attributes and the likelihood of subscribing to a term deposit?

# %%
# Encoding categorical variables
data_encoded = pd.get_dummies(data, drop_first=True)

# Calculating the correlation matrix
correlation_matrix = data_encoded.corr()

# Extracting the correlation with the target variable 'y_yes'
target_correlation = correlation_matrix['y_yes'].sort_values(ascending=False)
print("Top 10 positively correlated features:")
print(target_correlation.head(10))
print("\nTop 10 negatively correlated features:")
print(target_correlation.tail(10))

# %%
# Bar chart of top correlations with subscription (top 15 + bottom 15)
top_corr = pd.concat([target_correlation.head(11), target_correlation.tail(10)])
top_corr = top_corr.drop('y_yes')  # remove self

plt.figure(figsize=(14, 8))
colors = ['#5DC863' if v > 0 else '#3B528B' for v in top_corr.values]
plt.barh(top_corr.index, top_corr.values, color=colors)
plt.axvline(0, color='black', linewidth=0.8)
plt.title('Top Correlations with Term Deposit Subscription (y_yes)')
plt.xlabel('Pearson Correlation Coefficient')
plt.tight_layout()
plt.show()

# %%
# Full correlation heatmap
plt.figure(figsize=(14, 10))
# Use only numeric + key encoded columns to keep heatmap readable
key_cols = ['age', 'balance', 'duration', 'campaign', 'pdays', 'previous',
            'y_yes', 'housing_yes', 'loan_yes', 'default_yes',
            'poutcome_success', 'poutcome_failure', 'contact_telephone']
key_cols = [c for c in key_cols if c in data_encoded.columns]
sns.heatmap(data_encoded[key_cols].corr(), annot=True, fmt='.2f',
            cmap='viridis', linewidths=0.5)
plt.title('Correlation Matrix — Key Features vs Term Deposit Subscription')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 📊 Key Findings Summary
#
# | Finding | Value |
# |---|---|
# | Total clients | 45,216 |
# | Age range | 18 – 95 (mean: 40.9) |
# | Most common job | Blue-collar (9,732) |
# | Married clients | 60.2% |
# | Credit default rate | **1.80%** |
# | Average yearly balance | €1,362 (median: €448.5) |
# | Clients with housing loan | 55.6% |
# | Primary contact method | Cellular (64.8%) |
# | Most active campaign month | May (13,766 contacts) |
# | Subscription rate | **11.7%** (5,294 out of 45,216) |
# | Strongest predictor | `duration` (call length, r = 0.394) |
# | 2nd strongest predictor | `poutcome_success` (r = 0.307) |
#
# > 💡 **Key insight:** Longer calls and previous campaign success are the strongest signals of subscription.
